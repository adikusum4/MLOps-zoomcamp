# %%
# !python -V
# Out:
# Python 3.11.5

# %%
import pandas as pd
import numpy as np

# %%
import os
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

# %%
import mlflow
import mlflow.sklearn
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR
from sklearn.metrics import mean_squared_error, root_mean_squared_error
from sklearn.utils import resample
from scipy.sparse import csr_matrix

# %%
import xgboost as xgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location=('file:///C:/Users/Cokroaminoto/Documents/Analisis Data/Data '
#  'Scientist/DataTalksClub/MLOps - zoomcamp/02-experiment-tracking/mlruns/1'), creation_time=1727228916584, experiment_id='1', last_update_time=1727228916584, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
#df_train = read_dataframe('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-01.parquet')
#df_val = read_dataframe('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-02.parquet')

df_train = read_dataframe('/datasets/dtc/green_tripdata_2021-01.parquet')
df_val = read_dataframe('/datasets/dtc/green_tripdata_2021-02.parquet')

# %%
df_train.shape
# Out:
# (73908, 21)

# %%
df_val.shape
# Out:
# (61921, 21)

# %%
# Take 10% of the data randomly
df_train = df_train.sample(frac=0.1, random_state=42)
df_val = df_val.sample(frac=0.1, random_state=42)

# %%
df_train.shape
# Out:
# (7391, 21)

# %%
df_val.shape
# Out:
# (6192, 21)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# C:\Users\Cokroaminoto\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 9.486348156352333

# %%
# Create directories if they don't exist
try:
    os.makedirs('models/', exist_ok=True)
except Exception as e:
    print(f"Error creating models folder: {e}")

with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "adi")

    mlflow.log_param("train-data-path", "/datasets/dtc/green_tripdata_2021-01.parquet")
    #mlflow.log_param("train-data-path", "https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-01.parquet")
    mlflow.log_param("sample-size-train-data", df_train.shape[0])  # Record the number of samples taken
    mlflow.log_param("valid-data-path", "/datasets/dtc/green_tripdata_2021-02.parquet")
    #mlflow.log_param("valid-data-path", "https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-02.parquet")
    mlflow.log_param("sample-size-valid-data", df_valid.shape[0])  # Record the number of samples taken

    alpha = 0.1
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")
# Out:
# C:\Users\Cokroaminoto\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            #num_boost_round=1000,  # for processor multi-core Intel i5 with 8GB RAM or higher
            num_boost_round=200,  # Reduced from 1000 for processor Intel Celeron N3350 with 4GB RAM 
            evals=[(valid, 'validation')],
            #early_stopping_rounds=50  # for processor multi-core Intel i5 with 8GB RAM or higher 
            early_stopping_rounds=20  # Reduced from 50 for processor Intel Celeron N3350 with 4GB RAM 
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    #'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)), # for processor multi-core Intel i5 with 8GB RAM or higher
    'max_depth': scope.int(hp.quniform('max_depth', 4, 20, 1)),  # Reduced range for processor Intel Celeron N3350 with 4GB RAM 
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    #'objective': 'reg:linear', # older version
    'objective': 'reg:squarederror',  # newer version
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
#   0%|                                                                           | 0/50 [00:00<?, ?trial/s, best loss=?]
# C:\Users\Cokroaminoto\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:39:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:7.04451
# [1]	validation-rmse:6.91873
# [2]	validation-rmse:6.91370
# [3]	validation-rmse:6.91251
# [4]	validation-rmse:6.90556
# [5]	validation-rmse:6.89537
# [6]	validation-rmse:6.89635
# [7]	validation-rmse:6.89262
# [8]	validation-rmse:6.89484
# [9]	validation-rmse:6.88876
# [10]	validation-rmse:6.88670
# [11]	validation-rmse:6.89174
# [12]	validation-rmse:6.88690
# [13]	validation-rmse:6.88679
# [14]	validation-rmse:6.88119
# [15]	validation-rmse:6.88338
# [16]	validation-rmse:6.88161
# [17]	validation-rmse:6.88280
# [18]	validation-rmse:6.87876
# [19]	validation-rmse:6.87589
# [20]	validation-rmse:6.87721
# [21]	validation-rmse:6.87670
# [22]	validation-rmse:6.87909
# [23]	validation-rmse:6.87707
# [24]	validation-rmse:6.87785
# [25]	validation-rmse:6.88047
# [26]	validation-rmse:6.87614
# [27]	validation-rmse:6.87785
# [28]	validation-rmse:6.87643
# [29]	validation-rmse:6.87633
# [30]	validation-rmse:6.87679
# [31]	validation-rmse:6.87589
# [32]	validation-rmse:6.87472
# [33]	validation-rmse:6.87491
# [34]	validation-rmse:6.87411
# [35]	validation-rmse:6.87652
# [36]	validation-rmse:6.87502
# [37]	validation-rmse:6.87649
# [38]	validation-rmse:6.87612
# [39]	validation-rmse:6.87452
# [40]	validation-rmse:6.87563
# [41]	validation-rmse:6.87670
# [42]	validation-rmse:6.87912
# [43]	validation-rmse:6.87703
# [44]	validation-rmse:6.87730
# [45]	validation-rmse:6.87745
# [46]	validation-rmse:6.87668
# [47]	validation-rmse:6.87662
# [48]	validation-rmse:6.87630
# [49]	validation-rmse:6.87575
# [50]	validation-rmse:6.87704
# [51]	validation-rmse:6.87716
# [52]	validation-rmse:6.87518
# [53]	validation-rmse:6.87732
# [54]	validation-rmse:6.87684
#   0%|                                                                           | 0/50 [00:10<?, ?trial/s, best loss=?]
# C:\Users\Cokroaminoto\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#   2%|█                                                 | 1/50 [00:12<10:03, 12.33s/trial, best loss: 6.876838310257262]
# C:\Users\Cokroaminoto\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:40:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:10.31778
# [1]	validation-rmse:8.97836
# [2]	validation-rmse:8.15095
# [3]	validation-rmse:7.65286
# [4]	validation-rmse:7.35739
# [5]	validation-rmse:7.18476
# [6]	validation-rmse:7.07997
# [7]	validation-rmse:7.01487
# [8]	validation-rmse:6.97612
# [9]	validation-rmse:6.95001
# [10]	validation-rmse:6.92715
# [11]	validation-rmse:6.92024
# [12]	validation-rmse:6.91152
# [13]	validation-rmse:6.90732
# [14]	validation-rmse:6.90108
# [15]	validation-rmse:6.89906
# [16]	validation-rmse:6.89774
# [17]	validation-rmse:6.89705
# [18]	validation-rmse:6.89584
# [19]	validation-rmse:6.89531
# [20]	validation-rmse:6.89398
# [21]	validation-rmse:6.89387
# [22]	validation-rmse:6.89180
# [23]	validation-rmse:6.89382
# [24]	validation-rmse:6.89172
# [25]	validation-rmse:6.89184
# [26]	validation-rmse:6.89024
# [27]	validation-rmse:6.89178
# [28]	validation-rmse:6.89027
# [29]	validation-rmse:6.88864
# [30]	validation-rmse:6.88972
# [31]	validation-rmse:6.88808
# [32]	validation-rmse:6.88847
# [33]	validation-rmse:6.88737
# [34]	validation-rmse:6.88814
# [35]	validation-rmse:6.88654
# [36]	validation-rmse:6.88767
# [37]	validation-rmse:6.88660
# [38]	validation-rmse:6.88843
# [39]	validation-rmse:6.88692
# [40]	validation-rmse:6.88743
# [41]	validation-rmse:6.88610
# [42]	validation-rmse:6.88731
# [43]	validation-rmse:6.88635
# [44]	validation-rmse:6.88643
# [45]	validation-rmse:6.88519
# [46]	validation-rmse:6.88428
# [47]	validation-rmse:6.88598
# [48]	validation-rmse:6.88537
# [49]	validation-rmse:6.88660
# [50]	validation-rmse:6.88565
# [51]	validation-rmse:6.88656
# [52]	validation-rmse:6.88579
# [53]	validation-rmse:6.88678
# [54]	validation-rmse:6.88553
# [55]	validation-rmse:6.88524
# [56]	validation-rmse:6.88576
# [57]	validation-rmse:6.88501
# [58]	validation-rmse:6.88636
# [59]	validation-rmse:6.88598
# [60]	validation-rmse:6.88605
# [61]	validation-rmse:6.88479
# [62]	validation-rmse:6.88548
# [63]	validation-rmse:6.88463
# [64]	validation-rmse:6.88424
# [65]	validation-rmse:6.88516
# [66]	validation-rmse:6.88496
# [67]	validation-rmse:6.88571
# [68]	validation-rmse:6.88470
# [69]	validation-rmse:6.88492
# [70]	validation-rmse:6.88415
# [71]	validation-rmse:6.88565
# [72]	validation-rmse:6.88501
# [73]	validation-rmse:6.88509
# [74]	validation-rmse:6.88445
# [75]	validation-rmse:6.88468
# [76]	validation-rmse:6.88529
# [77]	validation-rmse:6.88488
# [78]	validation-rmse:6.88556
# [79]	validation-rmse:6.88480
# [80]	validation-rmse:6.88601
# [81]	validation-rmse:6.88405
# [82]	validation-rmse:6.88423
# [83]	validation-rmse:6.88394
# [84]	validation-rmse:6.88463
# [85]	validation-rmse:6.88416
# [86]	validation-rmse:6.88329
# [87]	validation-rmse:6.88264
# [88]	validation-rmse:6.88355
# [89]	validation-rmse:6.88302
# [90]	validation-rmse:6.88271
# [91]	validation-rmse:6.88245
# [92]	validation-rmse:6.88313
# [93]	validation-rmse:6.88273
# [94]	validation-rmse:6.88218
# [95]	validation-rmse:6.88255
# [96]	validation-rmse:6.88347
# [97]	validation-rmse:6.88428
# [98]	validation-rmse:6.88352
# [99]	validation-rmse:6.88383
# [100]	validation-rmse:6.88317
# [101]	validation-rmse:6.88346
# [102]	validation-rmse:6.88268
# [103]	validation-rmse:6.88198
# [104]	validation-rmse:6.88238
# [105]	validation-rmse:6.88292
# [106]	validation-rmse:6.88215
# [107]	validation-rmse:6.88248
# [108]	validation-rmse:6.88305
# [109]	validation-rmse:6.88217
# [110]	validation-rmse:6.88150
# [111]	validation-rmse:6.88073
# [112]	validation-rmse:6.88044
# [113]	validation-rmse:6.88159
# [114]	validation-rmse:6.88141
# [115]	validation-rmse:6.88094
# [116]	validation-rmse:6.88273
# [117]	validation-rmse:6.88223
# [118]	validation-rmse:6.88202
# [119]	validation-rmse:6.88109
# [120]	validation-rmse:6.88098
# [121]	validation-rmse:6.88157
# [122]	validation-rmse:6.88062
# [123]	validation-rmse:6.88123
# [124]	validation-rmse:6.88068
# [125]	validation-rmse:6.88067
# [126]	validation-rmse:6.88106
# [127]	validation-rmse:6.88147
# [128]	validation-rmse:6.88073
# [129]	validation-rmse:6.87988
# [130]	validation-rmse:6.88103
# [131]	validation-rmse:6.88086
# [132]	validation-rmse:6.88041
# [133]	validation-rmse:6.88044
# [134]	validation-rmse:6.88021
# [135]	validation-rmse:6.88027
# [136]	validation-rmse:6.88074
# [137]	validation-rmse:6.88121
# [138]	validation-rmse:6.88090
# [139]	validation-rmse:6.88110
# [140]	validation-rmse:6.88073
# [141]	validation-rmse:6.88082
# [142]	validation-rmse:6.88174
# [143]	validation-rmse:6.88085
# [144]	validation-rmse:6.87966
# [145]	validation-rmse:6.87947
# [146]	validation-rmse:6.87866
# [147]	validation-rmse:6.87955
# [148]	validation-rmse:6.87888
# [149]	validation-rmse:6.87905
# [150]	validation-rmse:6.87907
# [151]	validation-rmse:6.87859
# [152]	validation-rmse:6.87851
# [153]	validation-rmse:6.87858
# [154]	validation-rmse:6.87843
# [155]	validation-rmse:6.87858
# [156]	validation-rmse:6.87836
# [157]	validation-rmse:6.87817
# [158]	validation-rmse:6.87833
# [159]	validation-rmse:6.87888
# [160]	validation-rmse:6.87863
# [161]	validation-rmse:6.87891
# [162]	validation-rmse:6.87879
# [163]	validation-rmse:6.87937
# [164]	validation-rmse:6.87872
# [165]	validation-rmse:6.87850
# [166]	validation-rmse:6.87850
# [167]	validation-rmse:6.87900
# [168]	validation-rmse:6.87874
# [169]	validation-rmse:6.87848
# [170]	validation-rmse:6.87875
# [171]	validation-rmse:6.87850
# [172]	validation-rmse:6.87834
# [173]	validation-rmse:6.87847
# [174]	validation-rmse:6.87834
# [175]	validation-rmse:6.87880
# [176]	validation-rmse:6.87827
#   2%|█                                                 | 1/50 [00:43<10:03, 12.33s/trial, best loss: 6.876838310257262]
# C:\Users\Cokroaminoto\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#   4%|██                                                | 2/50 [00:44<19:16, 24.10s/trial, best loss: 6.876838310257262]
# C:\Users\Cokroaminoto\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:40:40] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:11.52874
# [1]	validation-rmse:10.77844
# [2]	validation-rmse:10.13954
# [3]	validation-rmse:9.59692
# [4]	validation-rmse:9.13984
# [5]	validation-rmse:8.75250
# [6]	validation-rmse:8.42580
# [7]	validation-rmse:8.15505
# [8]	validation-rmse:7.92995
# [9]	validation-rmse:7.74229
# [10]	validation-rmse:7.58760
# [11]	validation-rmse:7.45745
# [12]	validation-rmse:7.35069
# [13]	validation-rmse:7.26162
# [14]	validation-rmse:7.18955
# [15]	validation-rmse:7.12706
# [16]	validation-rmse:7.07462
# [17]	validation-rmse:7.03204
# [18]	validation-rmse:6.99657
# [19]	validation-rmse:6.96712
# [20]	validation-rmse:6.94544
# [21]	validation-rmse:6.92514
# [22]	validation-rmse:6.90973
# [23]	validation-rmse:6.89554
# [24]	validation-rmse:6.88432
# [25]	validation-rmse:6.87457
# [26]	validation-rmse:6.86659
# [27]	validation-rmse:6.86012
# [28]	validation-rmse:6.85439
# [29]	validation-rmse:6.84994
# [30]	validation-rmse:6.84577
# [31]	validation-rmse:6.84263
# [32]	validation-rmse:6.83861
# [33]	validation-rmse:6.83523
# [34]	validation-rmse:6.83251
# [35]	validation-rmse:6.83006
# [36]	validation-rmse:6.82822
# [37]	validation-rmse:6.82625
# [38]	validation-rmse:6.82566
# [39]	validation-rmse:6.82365
# [40]	validation-rmse:6.82282
# [41]	validation-rmse:6.82149
# [42]	validation-rmse:6.82085
# [43]	validation-rmse:6.82122
# [44]	validation-rmse:6.82051
# [45]	validation-rmse:6.82065
# [46]	validation-rmse:6.82010
# [47]	validation-rmse:6.81907
# [48]	validation-rmse:6.81923
# [49]	validation-rmse:6.81862
# [50]	validation-rmse:6.81855
# [51]	validation-rmse:6.81730
# [52]	validation-rmse:6.81858
# [53]	validation-rmse:6.81745
# [54]	validation-rmse:6.81672
# [55]	validation-rmse:6.81706
# [56]	validation-rmse:6.81682
# [57]	validation-rmse:6.81643
# [58]	validation-rmse:6.81639
# [59]	validation-rmse:6.81636
# [60]	validation-rmse:6.81473
# [61]	validation-rmse:6.81489
# [62]	validation-rmse:6.81429
# [63]	validation-rmse:6.81530
# [64]	validation-rmse:6.81581
# [65]	validation-rmse:6.81543
# [66]	validation-rmse:6.81484
# [67]	validation-rmse:6.81456
# [68]	validation-rmse:6.81488
# [69]	validation-rmse:6.81497
# [70]	validation-rmse:6.81460
# [71]	validation-rmse:6.81423
# [72]	validation-rmse:6.81506
# [73]	validation-rmse:6.81469
# [74]	validation-rmse:6.81506
# [75]	validation-rmse:6.81484
# [76]	validation-rmse:6.81497
# [77]	validation-rmse:6.81456
# [78]	validation-rmse:6.81569
# [79]	validation-rmse:6.81601
# [80]	validation-rmse:6.81530
# [81]	validation-rmse:6.81540
# [82]	validation-rmse:6.81506
# [83]	validation-rmse:6.81470
# [84]	validation-rmse:6.81471
# [85]	validation-rmse:6.81463
# [86]	validation-rmse:6.81475
# [87]	validation-rmse:6.81489
# [88]	validation-rmse:6.81482
# [89]	validation-rmse:6.81516
# [90]	validation-rmse:6.81532
# [91]	validation-rmse:6.81546
#   4%|██                                                | 2/50 [00:59<19:16, 24.10s/trial, best loss: 6.876838310257262]
# C:\Users\Cokroaminoto\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#   6%|███                                               | 3/50 [00:59<15:44, 20.09s/trial, best loss: 6.815460969919869]
# C:\Users\Cokroaminoto\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:40:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:11.49378
# [1]	validation-rmse:10.72227
# [2]	validation-rmse:10.06966
# [3]	validation-rmse:9.52100
# [4]	validation-rmse:9.06241
# [5]	validation-rmse:8.68080
# [6]	validation-rmse:8.36539
# [7]	validation-rmse:8.10546
# [8]	validation-rmse:7.89243
# [9]	validation-rmse:7.71811
# [10]	validation-rmse:7.57562
# [11]	validation-rmse:7.45940
# [12]	validation-rmse:7.36489
# [13]	validation-rmse:7.28798
# [14]	validation-rmse:7.22530
# [15]	validation-rmse:7.17427
# [16]	validation-rmse:7.13242
# [17]	validation-rmse:7.09803
# [18]	validation-rmse:7.06989
# [19]	validation-rmse:7.04656
# [20]	validation-rmse:7.02757
# [21]	validation-rmse:7.01181
# [22]	validation-rmse:6.99849
# [23]	validation-rmse:6.98760
# [24]	validation-rmse:6.97819
# [25]	validation-rmse:6.97018
# [26]	validation-rmse:6.96353
# [27]	validation-rmse:6.95792
# [28]	validation-rmse:6.95323
# [29]	validation-rmse:6.94905
# [30]	validation-rmse:6.94535
# [31]	validation-rmse:6.94220
# [32]	validation-rmse:6.93945
# [33]	validation-rmse:6.93724
# [34]	validation-rmse:6.93506
# [35]	validation-rmse:6.93328
# [36]	validation-rmse:6.93184
# [37]	validation-rmse:6.93033
# [38]	validation-rmse:6.92901
# [39]	validation-rmse:6.92803
# [40]	validation-rmse:6.92702
# [41]	validation-rmse:6.92598
# [42]	validation-rmse:6.92534
# [43]	validation-rmse:6.92442
# [44]	validation-rmse:6.92348
# [45]	validation-rmse:6.92287
# [46]	validation-rmse:6.92238
# [47]	validation-rmse:6.92219
# ...
# [22]	validation-rmse:6.88056
# [23]	validation-rmse:6.87128
# [24]	validation-rmse:6.86481
# [25]	validation-rmse:6.86007
# [26]	validation-rmse:6.85467
# [27]	validation-rmse:6.84955
# [28]	validation-rmse:6.84499
# [29]	validation-rmse:6.83875
# [30]	validation-rmse:6.83536
# [31]	validation-rmse:6.83311
# [32]	validation-rmse:6.83148
# [33]	validation-rmse:6.82884
# [34]	validation-rmse:6.82519
# [35]	validation-rmse:6.82698
# [36]	validation-rmse:6.82692
# [37]	validation-rmse:6.82627
# [38]	validation-rmse:6.82629
# [39]	validation-rmse:6.82537
# [40]	validation-rmse:6.82499
# [41]	validation-rmse:6.82326
# [42]	validation-rmse:6.82183
# [43]	validation-rmse:6.82296
# [44]	validation-rmse:6.82209
# [45]	validation-rmse:6.82170
# [46]	validation-rmse:6.82149
# [47]	validation-rmse:6.82148
# [48]	validation-rmse:6.82189
# [49]	validation-rmse:6.82164
# [50]	validation-rmse:6.82162
# [51]	validation-rmse:6.82092
# [52]	validation-rmse:6.81929
# [53]	validation-rmse:6.81952
# [54]	validation-rmse:6.81958
# [55]	validation-rmse:6.81944
# [56]	validation-rmse:6.81864
# [57]	validation-rmse:6.81806
# [58]	validation-rmse:6.81777
# [59]	validation-rmse:6.81709
# [60]	validation-rmse:6.81764
# [61]	validation-rmse:6.81754
# [62]	validation-rmse:6.81668
# [63]	validation-rmse:6.81673
# [64]	validation-rmse:6.81637
# [65]	validation-rmse:6.81522
# [66]	validation-rmse:6.81401
# [67]	validation-rmse:6.81334
# [68]	validation-rmse:6.81417
# [69]	validation-rmse:6.81428
# [70]	validation-rmse:6.81432
# [71]	validation-rmse:6.81390
# [72]	validation-rmse:6.81412
# [73]	validation-rmse:6.81422
# [74]	validation-rmse:6.81345
# [75]	validation-rmse:6.81322
# [76]	validation-rmse:6.81256
# [77]	validation-rmse:6.81315
# [78]	validation-rmse:6.81338
# [79]	validation-rmse:6.81302
# [80]	validation-rmse:6.81294
# [81]	validation-rmse:6.81248
# [82]	validation-rmse:6.81182
# [83]	validation-rmse:6.81202
# [84]	validation-rmse:6.81130
# [85]	validation-rmse:6.81118
# [86]	validation-rmse:6.81170
# [87]	validation-rmse:6.81128
# [88]	validation-rmse:6.81128
# [89]	validation-rmse:6.81124
# [90]	validation-rmse:6.81045
# [91]	validation-rmse:6.80980
# [92]	validation-rmse:6.81053
# [93]	validation-rmse:6.80951
# [94]	validation-rmse:6.80923
# [95]	validation-rmse:6.80841
# [96]	validation-rmse:6.80727
# [97]	validation-rmse:6.80854
# [98]	validation-rmse:6.80798
# [99]	validation-rmse:6.80824
# [100]	validation-rmse:6.80779
# [101]	validation-rmse:6.80782
# [102]	validation-rmse:6.80808
# [103]	validation-rmse:6.80754
# [104]	validation-rmse:6.80710
# [105]	validation-rmse:6.80664
# [106]	validation-rmse:6.80703
# [107]	validation-rmse:6.80689
# [108]	validation-rmse:6.80708
# [109]	validation-rmse:6.80666
# [110]	validation-rmse:6.80666
# [111]	validation-rmse:6.80587
# [112]	validation-rmse:6.80587
# [113]	validation-rmse:6.80536
# [114]	validation-rmse:6.80552
# [115]	validation-rmse:6.80484
# [116]	validation-rmse:6.80525
# [117]	validation-rmse:6.80511
# [118]	validation-rmse:6.80507
# [119]	validation-rmse:6.80541
# [120]	validation-rmse:6.80480
# [121]	validation-rmse:6.80555
# [122]	validation-rmse:6.80547
# [123]	validation-rmse:6.80544
# [124]	validation-rmse:6.80423
# [125]	validation-rmse:6.80371
# [126]	validation-rmse:6.80390
# [127]	validation-rmse:6.80315
# [128]	validation-rmse:6.80199
# [129]	validation-rmse:6.80159
# [130]	validation-rmse:6.80243
# [131]	validation-rmse:6.80269
# [132]	validation-rmse:6.80279
# [133]	validation-rmse:6.80221
# [134]	validation-rmse:6.80170
# [135]	validation-rmse:6.80286
# [136]	validation-rmse:6.80259
# [137]	validation-rmse:6.80262
# [138]	validation-rmse:6.80229
# [139]	validation-rmse:6.80260
# [140]	validation-rmse:6.80248
# [141]	validation-rmse:6.80245
# [142]	validation-rmse:6.80289
# [143]	validation-rmse:6.80291
# [144]	validation-rmse:6.80254
# [145]	validation-rmse:6.80270
# [146]	validation-rmse:6.80296
# [147]	validation-rmse:6.80209
# [148]	validation-rmse:6.80228
# [149]	validation-rmse:6.80161
#  98%|█████████████████████████████████████████████████ | 49/50 [14:57<00:22, 22.51s/trial, best loss: 6.78515925152334]
# C:\Users\Cokroaminoto\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████| 50/50 [14:58<00:00, 17.97s/trial, best loss: 6.78515925152334]

# %%
mlflow.xgboost.autolog(disable=True)

# %%
def objective(params):
    #mlflow.end_run()  # End the previous run if it exists
    with mlflow.start_run(nested=True): # Use Nested Runs
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=200,
            evals=[(valid, 'validation')],
            early_stopping_rounds=20
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
    return {'loss': rmse, 'status': STATUS_OK}

# %%
with mlflow.start_run():
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    #best_params = {
    #    'learning_rate': 0.09585355369315604,
    #    'max_depth': 30,
    #    'min_child_weight': 1.060597050922164,
    #    'objective': 'reg:linear',
    #    'reg_alpha': 0.018060244040060163,
    #    'reg_lambda': 0.011658731377413597,
    #    'seed': 42
    #}
    # Using best_result to set best_params
    best_params = {
        'learning_rate': best_result['learning_rate'],
        'max_depth': int(best_result['max_depth']),  # Make sure to convert to int
        'min_child_weight': best_result['min_child_weight'],
        #'objective': 'reg:linear', #older version
        'objective': 'reg:squarederror',  
        'reg_alpha': best_result['reg_alpha'],
        'reg_lambda': best_result['reg_lambda'],
        'seed': 42
    }

    best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=200, #1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=20 #50
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
#   0%|                                                                           | 0/50 [00:00<?, ?trial/s, best loss=?]
# C:\Users\Cokroaminoto\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:09:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:7.13259
# [1]	validation-rmse:6.91844
# [2]	validation-rmse:6.90432
# [3]	validation-rmse:6.89006
# [4]	validation-rmse:6.87571
# [5]	validation-rmse:6.87444
# [6]	validation-rmse:6.87527
# [7]	validation-rmse:6.87217
# [8]	validation-rmse:6.87226
# [9]	validation-rmse:6.87314
# [10]	validation-rmse:6.86691
# [11]	validation-rmse:6.87107
# [12]	validation-rmse:6.86351
# [13]	validation-rmse:6.86770
# [14]	validation-rmse:6.86279
# [15]	validation-rmse:6.86655
# [16]	validation-rmse:6.86335
# [17]	validation-rmse:6.86757
# [18]	validation-rmse:6.86411
# [19]	validation-rmse:6.86142
# [20]	validation-rmse:6.86122
# [21]	validation-rmse:6.86593
# [22]	validation-rmse:6.86104
# [23]	validation-rmse:6.86342
# [24]	validation-rmse:6.86760
# [25]	validation-rmse:6.86226
# [26]	validation-rmse:6.86298
# [27]	validation-rmse:6.86078
# [28]	validation-rmse:6.86092
# [29]	validation-rmse:6.85884
# [30]	validation-rmse:6.85933
# [31]	validation-rmse:6.86530
# [32]	validation-rmse:6.86140
# [33]	validation-rmse:6.86100
# [34]	validation-rmse:6.86068
# [35]	validation-rmse:6.86261
# [36]	validation-rmse:6.86617
# [37]	validation-rmse:6.86110
# [38]	validation-rmse:6.86432
# [39]	validation-rmse:6.85927
# [40]	validation-rmse:6.86178
# [41]	validation-rmse:6.86003
# [42]	validation-rmse:6.86053
# [43]	validation-rmse:6.86417
# [44]	validation-rmse:6.86625
# [45]	validation-rmse:6.86365
# [46]	validation-rmse:6.86400
# [47]	validation-rmse:6.86276
# [48]	validation-rmse:6.86325
#   0%|                                                                           | 0/50 [00:08<?, ?trial/s, best loss=?]
# C:\Users\Cokroaminoto\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#   2%|█                                                 | 1/50 [00:09<07:39,  9.39s/trial, best loss: 6.864888798804896]
# C:\Users\Cokroaminoto\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:09:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:9.38116
# [1]	validation-rmse:7.96889
# [2]	validation-rmse:7.35823
# [3]	validation-rmse:7.10112
# [4]	validation-rmse:6.99412
# [5]	validation-rmse:6.93926
# [6]	validation-rmse:6.91070
# [7]	validation-rmse:6.89804
# [8]	validation-rmse:6.89273
# [9]	validation-rmse:6.88908
# [10]	validation-rmse:6.88543
# [11]	validation-rmse:6.88334
# [12]	validation-rmse:6.87672
# [13]	validation-rmse:6.87645
# [14]	validation-rmse:6.87727
# [15]	validation-rmse:6.87767
# [16]	validation-rmse:6.87626
# [17]	validation-rmse:6.87424
# [18]	validation-rmse:6.87366
# [19]	validation-rmse:6.87383
# [20]	validation-rmse:6.87132
# [21]	validation-rmse:6.87183
# [22]	validation-rmse:6.87282
# [23]	validation-rmse:6.87131
# [24]	validation-rmse:6.86980
# [25]	validation-rmse:6.86970
# [26]	validation-rmse:6.87023
# [27]	validation-rmse:6.87126
# [28]	validation-rmse:6.86923
# [29]	validation-rmse:6.87116
# [30]	validation-rmse:6.86873
# [31]	validation-rmse:6.87052
# [32]	validation-rmse:6.86808
# [33]	validation-rmse:6.87053
# [34]	validation-rmse:6.86922
# [35]	validation-rmse:6.87096
# [36]	validation-rmse:6.86817
# [37]	validation-rmse:6.86848
# [38]	validation-rmse:6.86712
# [39]	validation-rmse:6.86871
# [40]	validation-rmse:6.86725
# [41]	validation-rmse:6.86678
# [42]	validation-rmse:6.86541
# [43]	validation-rmse:6.86586
# [44]	validation-rmse:6.86409
# [45]	validation-rmse:6.86514
# [46]	validation-rmse:6.86490
# [47]	validation-rmse:6.86559
# [48]	validation-rmse:6.86463
# [49]	validation-rmse:6.86574
# [50]	validation-rmse:6.86520
# [51]	validation-rmse:6.86636
# [52]	validation-rmse:6.86454
# [53]	validation-rmse:6.86553
# [54]	validation-rmse:6.86452
# [55]	validation-rmse:6.86486
# [56]	validation-rmse:6.86422
# [57]	validation-rmse:6.86568
# [58]	validation-rmse:6.86456
# [59]	validation-rmse:6.86564
# [60]	validation-rmse:6.86503
# [61]	validation-rmse:6.86570
# [62]	validation-rmse:6.86541
# [63]	validation-rmse:6.86712
# [64]	validation-rmse:6.86655
#   2%|█                                                 | 1/50 [00:17<07:39,  9.39s/trial, best loss: 6.864888798804896]
# C:\Users\Cokroaminoto\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#   4%|██                                                | 2/50 [00:18<07:20,  9.18s/trial, best loss: 6.864888798804896]
# C:\Users\Cokroaminoto\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:10:08] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:7.28497
# [1]	validation-rmse:6.96226
# [2]	validation-rmse:6.93456
# [3]	validation-rmse:6.92739
# [4]	validation-rmse:6.91899
# [5]	validation-rmse:6.92177
# [6]	validation-rmse:6.91899
# [7]	validation-rmse:6.91486
# [8]	validation-rmse:6.91905
# [9]	validation-rmse:6.91361
# [10]	validation-rmse:6.91627
# [11]	validation-rmse:6.91367
# [12]	validation-rmse:6.91545
# [13]	validation-rmse:6.91428
# [14]	validation-rmse:6.91148
# [15]	validation-rmse:6.91365
# [16]	validation-rmse:6.91612
# [17]	validation-rmse:6.91355
# [18]	validation-rmse:6.91183
# [19]	validation-rmse:6.91266
# [20]	validation-rmse:6.90886
# [21]	validation-rmse:6.90917
# [22]	validation-rmse:6.90737
# [23]	validation-rmse:6.90944
# [24]	validation-rmse:6.90748
# [25]	validation-rmse:6.90625
# [26]	validation-rmse:6.90763
# [27]	validation-rmse:6.90629
# [28]	validation-rmse:6.90545
# [29]	validation-rmse:6.90572
# [30]	validation-rmse:6.90362
# [31]	validation-rmse:6.90605
# [32]	validation-rmse:6.90500
# [33]	validation-rmse:6.90546
# [34]	validation-rmse:6.90509
# [35]	validation-rmse:6.90434
# [36]	validation-rmse:6.90517
# [37]	validation-rmse:6.90466
# [38]	validation-rmse:6.90609
# [39]	validation-rmse:6.90474
# [40]	validation-rmse:6.90340
# [41]	validation-rmse:6.90492
# [42]	validation-rmse:6.90362
# [43]	validation-rmse:6.90278
# [44]	validation-rmse:6.90287
# [45]	validation-rmse:6.90359
# [46]	validation-rmse:6.90426
# [47]	validation-rmse:6.90295
# [48]	validation-rmse:6.90369
# [49]	validation-rmse:6.90440
# [50]	validation-rmse:6.90339
# [51]	validation-rmse:6.90372
# [52]	validation-rmse:6.90315
# [53]	validation-rmse:6.90277
# [54]	validation-rmse:6.90362
# [55]	validation-rmse:6.90287
# [56]	validation-rmse:6.90236
# [57]	validation-rmse:6.90187
# [58]	validation-rmse:6.90141
# [59]	validation-rmse:6.90062
# [60]	validation-rmse:6.90118
# [61]	validation-rmse:6.90186
# [62]	validation-rmse:6.90269
# [63]	validation-rmse:6.90106
# [64]	validation-rmse:6.90154
# [65]	validation-rmse:6.90092
# [66]	validation-rmse:6.90152
# [67]	validation-rmse:6.90033
# [68]	validation-rmse:6.90152
# [69]	validation-rmse:6.90182
# [70]	validation-rmse:6.90214
# [71]	validation-rmse:6.90239
# [72]	validation-rmse:6.90252
# [73]	validation-rmse:6.90108
# [74]	validation-rmse:6.90014
# [75]	validation-rmse:6.90055
# [76]	validation-rmse:6.90236
# [77]	validation-rmse:6.90185
# [78]	validation-rmse:6.90088
# [79]	validation-rmse:6.90082
# [80]	validation-rmse:6.89939
# [81]	validation-rmse:6.89960
# [82]	validation-rmse:6.90068
# [83]	validation-rmse:6.90096
# [84]	validation-rmse:6.90050
# [85]	validation-rmse:6.90087
# [86]	validation-rmse:6.90052
# [87]	validation-rmse:6.90028
# [88]	validation-rmse:6.90048
# [89]	validation-rmse:6.90043
# [90]	validation-rmse:6.90067
# [91]	validation-rmse:6.90067
# [92]	validation-rmse:6.90118
# [93]	validation-rmse:6.90194
# [94]	validation-rmse:6.90182
# [95]	validation-rmse:6.90151
# [96]	validation-rmse:6.90162
# [97]	validation-rmse:6.90037
# [98]	validation-rmse:6.90122
# [99]	validation-rmse:6.90000
# [100]	validation-rmse:6.90142
#   4%|██                                                | 2/50 [00:31<07:20,  9.18s/trial, best loss: 6.864888798804896]
# C:\Users\Cokroaminoto\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#   6%|███                                               | 3/50 [00:31<08:36, 10.99s/trial, best loss: 6.864888798804896]
# C:\Users\Cokroaminoto\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:10:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:11.47917
# [1]	validation-rmse:10.69723
# [2]	validation-rmse:10.03749
# [3]	validation-rmse:9.48544
# [4]	validation-rmse:9.02575
# [5]	validation-rmse:8.63778
# [6]	validation-rmse:8.31242
# [7]	validation-rmse:8.05349
# [8]	validation-rmse:7.84038
# [9]	validation-rmse:7.66543
# [10]	validation-rmse:7.52557
# [11]	validation-rmse:7.40869
# [12]	validation-rmse:7.31296
# [13]	validation-rmse:7.23117
# [14]	validation-rmse:7.16750
# [15]	validation-rmse:7.11690
# [16]	validation-rmse:7.07090
# [17]	validation-rmse:7.03734
# [18]	validation-rmse:7.00543
# [19]	validation-rmse:6.98230
# [20]	validation-rmse:6.96333
# [21]	validation-rmse:6.94613
# [22]	validation-rmse:6.93103
# [23]	validation-rmse:6.92067
# [24]	validation-rmse:6.91086
# [25]	validation-rmse:6.90348
# [26]	validation-rmse:6.89862
# [27]	validation-rmse:6.88962
# [28]	validation-rmse:6.88264
# [29]	validation-rmse:6.87804
# [30]	validation-rmse:6.87541
# [31]	validation-rmse:6.87317
# [32]	validation-rmse:6.87154
# [33]	validation-rmse:6.86825
# [34]	validation-rmse:6.86647
# [35]	validation-rmse:6.86406
# [36]	validation-rmse:6.86397
# [37]	validation-rmse:6.86293
# [38]	validation-rmse:6.86232
# [39]	validation-rmse:6.86155
# [40]	validation-rmse:6.86105
# [41]	validation-rmse:6.86097
# [42]	validation-rmse:6.86147
# [43]	validation-rmse:6.86099
# [44]	validation-rmse:6.86065
# [45]	validation-rmse:6.85841
# [46]	validation-rmse:6.85867
# [47]	validation-rmse:6.85795
# [48]	validation-rmse:6.85783
# [49]	validation-rmse:6.85570
# [50]	validation-rmse:6.85591
# [51]	validation-rmse:6.85468
# [52]	validation-rmse:6.85414
# [53]	validation-rmse:6.85332
# [54]	validation-rmse:6.85338
# [55]	validation-rmse:6.85390
# [56]	validation-rmse:6.85192
# [57]	validation-rmse:6.85144
# [58]	validation-rmse:6.85091
# [59]	validation-rmse:6.85080
# [60]	validation-rmse:6.84966
# [61]	validation-rmse:6.84898
# [62]	validation-rmse:6.84801
# [63]	validation-rmse:6.84850
# [64]	validation-rmse:6.84839
# [65]	validation-rmse:6.84949
# [66]	validation-rmse:6.84809
# [67]	validation-rmse:6.84775
# [68]	validation-rmse:6.84810
# [69]	validation-rmse:6.84800
# [70]	validation-rmse:6.84815
# [71]	validation-rmse:6.84903
# [72]	validation-rmse:6.84876
# [73]	validation-rmse:6.84883
# [74]	validation-rmse:6.84932
# [75]	validation-rmse:6.84925
# [76]	validation-rmse:6.84796
# [77]	validation-rmse:6.84775
# [78]	validation-rmse:6.84762
# [79]	validation-rmse:6.84585
# [80]	validation-rmse:6.84530
# [81]	validation-rmse:6.84554
# [82]	validation-rmse:6.84429
# [83]	validation-rmse:6.84398
# [84]	validation-rmse:6.84402
# [85]	validation-rmse:6.84311
# [86]	validation-rmse:6.84329
# [87]	validation-rmse:6.84274
# [88]	validation-rmse:6.84312
# [89]	validation-rmse:6.84349
# [90]	validation-rmse:6.84353
# [91]	validation-rmse:6.84355
# [92]	validation-rmse:6.84319
# [93]	validation-rmse:6.84328
# [94]	validation-rmse:6.84273
# [95]	validation-rmse:6.84302
# [96]	validation-rmse:6.84324
# [97]	validation-rmse:6.84344
# [98]	validation-rmse:6.84355
# [99]	validation-rmse:6.84300
# [100]	validation-rmse:6.84261
# [101]	validation-rmse:6.84183
# [102]	validation-rmse:6.84128
# [103]	validation-rmse:6.84033
# [104]	validation-rmse:6.83970
# [105]	validation-rmse:6.83991
# [106]	validation-rmse:6.84043
# [107]	validation-rmse:6.83986
# [108]	validation-rmse:6.84008
# [109]	validation-rmse:6.83912
# [110]	validation-rmse:6.83896
# [111]	validation-rmse:6.83940
# [112]	validation-rmse:6.83804
# [113]	validation-rmse:6.83999
# [114]	validation-rmse:6.83919
# [115]	validation-rmse:6.83947
# [116]	validation-rmse:6.83798
# [117]	validation-rmse:6.83842
# [118]	validation-rmse:6.83882
# [119]	validation-rmse:6.83807
# [120]	validation-rmse:6.83827
# [121]	validation-rmse:6.83906
# [122]	validation-rmse:6.83783
# [123]	validation-rmse:6.83717
# [124]	validation-rmse:6.83758
# [125]	validation-rmse:6.83826
# [126]	validation-rmse:6.83805
# [127]	validation-rmse:6.83855
# [128]	validation-rmse:6.83882
# [129]	validation-rmse:6.83846
# [130]	validation-rmse:6.83790
# [131]	validation-rmse:6.83713
# [132]	validation-rmse:6.83700
# [133]	validation-rmse:6.83592
# [134]	validation-rmse:6.83408
# [135]	validation-rmse:6.83432
# [136]	validation-rmse:6.83411
# [137]	validation-rmse:6.83347
# [138]	validation-rmse:6.83343
# [139]	validation-rmse:6.83358
# [140]	validation-rmse:6.83220
# [141]	validation-rmse:6.83156
# [142]	validation-rmse:6.83158
# [143]	validation-rmse:6.83160
# [144]	validation-rmse:6.83178
# [145]	validation-rmse:6.83093
# [146]	validation-rmse:6.83094
# [147]	validation-rmse:6.83070
# [148]	validation-rmse:6.83074
# [149]	validation-rmse:6.83096
# [150]	validation-rmse:6.83051
# [151]	validation-rmse:6.82959
# [152]	validation-rmse:6.82970
# [153]	validation-rmse:6.82996
# [154]	validation-rmse:6.82978
# [155]	validation-rmse:6.83001
# [156]	validation-rmse:6.82983
# ...
# [127]	validation-rmse:6.80432
# [128]	validation-rmse:6.80469
# [129]	validation-rmse:6.80265
# [130]	validation-rmse:6.80194
# [131]	validation-rmse:6.80125
# [132]	validation-rmse:6.80154
# [133]	validation-rmse:6.80149
# [134]	validation-rmse:6.80136
# [135]	validation-rmse:6.80157
# [136]	validation-rmse:6.80148
# [137]	validation-rmse:6.80162
# [138]	validation-rmse:6.80106
# [139]	validation-rmse:6.80104
# [140]	validation-rmse:6.80104
# [141]	validation-rmse:6.79975
# [142]	validation-rmse:6.79925
# [143]	validation-rmse:6.79915
# [144]	validation-rmse:6.79942
# [145]	validation-rmse:6.79938
# [146]	validation-rmse:6.79911
# [147]	validation-rmse:6.79882
# [148]	validation-rmse:6.79896
# [149]	validation-rmse:6.79849
# [150]	validation-rmse:6.79909
# [151]	validation-rmse:6.79879
# [152]	validation-rmse:6.79874
# [153]	validation-rmse:6.79908
# [154]	validation-rmse:6.79877
# [155]	validation-rmse:6.79859
# [156]	validation-rmse:6.79805
# [157]	validation-rmse:6.79790
# [158]	validation-rmse:6.79755
# [159]	validation-rmse:6.79762
# [160]	validation-rmse:6.79737
# [161]	validation-rmse:6.79705
# [162]	validation-rmse:6.79648
# [163]	validation-rmse:6.79619
# [164]	validation-rmse:6.79607
# [165]	validation-rmse:6.79597
# [166]	validation-rmse:6.79538
# [167]	validation-rmse:6.79525
# [168]	validation-rmse:6.79542
# [169]	validation-rmse:6.79546
# [170]	validation-rmse:6.79519
# [171]	validation-rmse:6.79554
# [172]	validation-rmse:6.79453
# [173]	validation-rmse:6.79401
# [174]	validation-rmse:6.79364
# [175]	validation-rmse:6.79359
# [176]	validation-rmse:6.79315
# [177]	validation-rmse:6.79268
# [178]	validation-rmse:6.79275
# [179]	validation-rmse:6.79328
# [180]	validation-rmse:6.79291
# [181]	validation-rmse:6.79301
# [182]	validation-rmse:6.79283
# [183]	validation-rmse:6.79270
# [184]	validation-rmse:6.79283
# [185]	validation-rmse:6.79370
# [186]	validation-rmse:6.79343
# [187]	validation-rmse:6.79206
# [188]	validation-rmse:6.79207
# [189]	validation-rmse:6.79177
# [190]	validation-rmse:6.79179
# [191]	validation-rmse:6.79171
# [192]	validation-rmse:6.79157
# [193]	validation-rmse:6.79167
# [194]	validation-rmse:6.79157
# [195]	validation-rmse:6.79160
# [196]	validation-rmse:6.79178
# [197]	validation-rmse:6.79131
# [198]	validation-rmse:6.79092
# [199]	validation-rmse:6.79068
#  98%|████████████████████████████████████████████████ | 49/50 [09:45<00:12, 12.54s/trial, best loss: 6.790096051333509]
# C:\Users\Cokroaminoto\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 100%|█████████████████████████████████████████████████| 50/50 [09:45<00:00, 11.71s/trial, best loss: 6.790096051333509]
# [0]	validation-rmse:9.99779
# [1]	validation-rmse:8.58895
# [2]	validation-rmse:7.80349
# [3]	validation-rmse:7.37479
# [4]	validation-rmse:7.14621
# [5]	validation-rmse:7.01258
# [6]	validation-rmse:6.94435
# [7]	validation-rmse:6.90516
# [8]	validation-rmse:6.87912
# [9]	validation-rmse:6.86029
# [10]	validation-rmse:6.85335
# [11]	validation-rmse:6.84362
# [12]	validation-rmse:6.84287
# [13]	validation-rmse:6.84243
# [14]	validation-rmse:6.84169
# [15]	validation-rmse:6.83336
# [16]	validation-rmse:6.83549
# [17]	validation-rmse:6.83595
# [18]	validation-rmse:6.83437
# [19]	validation-rmse:6.83373
# [20]	validation-rmse:6.83162
# [21]	validation-rmse:6.82980
# [22]	validation-rmse:6.82709
# [23]	validation-rmse:6.82711
# [24]	validation-rmse:6.82633
# [25]	validation-rmse:6.82577
# [26]	validation-rmse:6.82432
# [27]	validation-rmse:6.82308
# [28]	validation-rmse:6.82216
# [29]	validation-rmse:6.81941
# [30]	validation-rmse:6.81942
# [31]	validation-rmse:6.81960
# [32]	validation-rmse:6.81878
# [33]	validation-rmse:6.81860
# [34]	validation-rmse:6.81832
# [35]	validation-rmse:6.81864
# [36]	validation-rmse:6.81417
# [37]	validation-rmse:6.81546
# [38]	validation-rmse:6.81355
# [39]	validation-rmse:6.81350
# [40]	validation-rmse:6.81399
# [41]	validation-rmse:6.81318
# [42]	validation-rmse:6.81329
# [43]	validation-rmse:6.81267
# [44]	validation-rmse:6.81200
# [45]	validation-rmse:6.81135
# [46]	validation-rmse:6.81129
# [47]	validation-rmse:6.81104
# [48]	validation-rmse:6.81065
# [49]	validation-rmse:6.80944
# [50]	validation-rmse:6.81039
# [51]	validation-rmse:6.81050
# [52]	validation-rmse:6.80986
# [53]	validation-rmse:6.80849
# [54]	validation-rmse:6.80709
# [55]	validation-rmse:6.80658
# [56]	validation-rmse:6.80632
# [57]	validation-rmse:6.80655
# [58]	validation-rmse:6.80576
# [59]	validation-rmse:6.80596
# [60]	validation-rmse:6.80190
# [61]	validation-rmse:6.80251
# [62]	validation-rmse:6.80199
# [63]	validation-rmse:6.80231
# [64]	validation-rmse:6.80193
# [65]	validation-rmse:6.79941
# [66]	validation-rmse:6.79896
# [67]	validation-rmse:6.79784
# [68]	validation-rmse:6.79759
# [69]	validation-rmse:6.79789
# [70]	validation-rmse:6.79722
# [71]	validation-rmse:6.79575
# [72]	validation-rmse:6.79533
# [73]	validation-rmse:6.79516
# [74]	validation-rmse:6.79518
# [75]	validation-rmse:6.79501
# [76]	validation-rmse:6.79593
# [77]	validation-rmse:6.79597
# [78]	validation-rmse:6.79619
# [79]	validation-rmse:6.79645
# [80]	validation-rmse:6.79511
# [81]	validation-rmse:6.79508
# [82]	validation-rmse:6.79445
# [83]	validation-rmse:6.79440
# [84]	validation-rmse:6.79393
# [85]	validation-rmse:6.79426
# [86]	validation-rmse:6.79386
# [87]	validation-rmse:6.79343
# [88]	validation-rmse:6.79266
# [89]	validation-rmse:6.79527
# [90]	validation-rmse:6.79392
# [91]	validation-rmse:6.79416
# [92]	validation-rmse:6.79336
# [93]	validation-rmse:6.79319
# [94]	validation-rmse:6.79223
# [95]	validation-rmse:6.79195
# [96]	validation-rmse:6.78923
# [97]	validation-rmse:6.78886
# [98]	validation-rmse:6.78850
# [99]	validation-rmse:6.78831
# [100]	validation-rmse:6.78905
# [101]	validation-rmse:6.78885
# [102]	validation-rmse:6.78901
# [103]	validation-rmse:6.78855
# [104]	validation-rmse:6.78833
# [105]	validation-rmse:6.78851
# [106]	validation-rmse:6.78876
# [107]	validation-rmse:6.78842
# [108]	validation-rmse:6.78748
# [109]	validation-rmse:6.78748
# [110]	validation-rmse:6.78738
# [111]	validation-rmse:6.78910
# [112]	validation-rmse:6.78905
# [113]	validation-rmse:6.78885
# [114]	validation-rmse:6.78911
# [115]	validation-rmse:6.78839
# [116]	validation-rmse:6.78805
# [117]	validation-rmse:6.78790
# [118]	validation-rmse:6.78778
# [119]	validation-rmse:6.78700
# [120]	validation-rmse:6.78758
# [121]	validation-rmse:6.78851
# [122]	validation-rmse:6.78802
# [123]	validation-rmse:6.78816
# [124]	validation-rmse:6.78859
# [125]	validation-rmse:6.78876
# [126]	validation-rmse:6.78825
# [127]	validation-rmse:6.78784
# [128]	validation-rmse:6.78802
# [129]	validation-rmse:6.78757
# [130]	validation-rmse:6.78648
# [131]	validation-rmse:6.78594
# [132]	validation-rmse:6.78519
# [133]	validation-rmse:6.78548
# [134]	validation-rmse:6.78592
# [135]	validation-rmse:6.78534
# [136]	validation-rmse:6.78627
# [137]	validation-rmse:6.78567
# [138]	validation-rmse:6.78466
# [139]	validation-rmse:6.78448
# [140]	validation-rmse:6.78538
# [141]	validation-rmse:6.78508
# [142]	validation-rmse:6.78505
# [143]	validation-rmse:6.78498
# [144]	validation-rmse:6.78500
# [145]	validation-rmse:6.78459
# [146]	validation-rmse:6.78526
# [147]	validation-rmse:6.78482
# [148]	validation-rmse:6.78515
# [149]	validation-rmse:6.78480
# [150]	validation-rmse:6.78515
# [151]	validation-rmse:6.78505
# [152]	validation-rmse:6.78566
# [153]	validation-rmse:6.78531
# [154]	validation-rmse:6.78545
# [155]	validation-rmse:6.78519
# [156]	validation-rmse:6.78556
# [157]	validation-rmse:6.78517
# [158]	validation-rmse:6.78496
# [159]	validation-rmse:6.78516
# C:\Users\Cokroaminoto\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# C:\Users\Cokroaminoto\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:19:40] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
# 2024/09/26 15:21:04 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# '\nwith mlflow.start_run():\n    best_result[\'max_depth\'] = int(best_result[\'max_depth\'])  # Ensure max_depth is an integer\n    mlflow.log_params(best_result)\n    booster = xgb.train(\n        params=best_result,\n        dtrain=train,\n        #num_boost_round=1000, # for processor multi-core Intel i5 with 8GB RAM or higher\n        num_boost_round=200,  # Reduced from 1000 for processor Intel Celeron N3350 with 4GB RAM \n        evals=[(valid, \'validation\')],\n        #early_stopping_rounds=50 # for processor multi-core Intel i5 with 8GB RAM or higher\n        early_stopping_rounds=20  # Reduced from 50 for processor Intel Celeron N3350 with 4GB RAM \n    )\n    y_pred = booster.predict(valid)\n    rmse = mean_squared_error(y_val, y_pred, squared=False)\n    mlflow.log_metric("rmse", rmse)\n\n    with open("models/preprocessor.b", "wb") as f_out:\n        pickle.dump(dv, f_out)\n    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")\n\n    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")\n'

# %%
#mlflow.sklearn.autolog(log_input_examples=False)  # Disable logging of input examples
mlflow.sklearn.autolog() # Enable automatic logging

# Print shapes for debugging
print("Shape of X_train before any transformation:", X_train.shape)
print("Shape of y_train before any transformation:", y_train.shape)

# If X_train and X_val are sparse matrices, convert them to dense
if isinstance(X_train, csr_matrix):
    X_train_dense = X_train.toarray()
else:
    X_train_dense = X_train

if isinstance(X_val, csr_matrix):
    X_val_dense = X_val.toarray()
else:
    X_val_dense = X_val

# Check shapes after conversion
print("Shape of X_train_dense after conversion:", X_train_dense.shape)
print("Shape of y_train after conversion:", y_train.shape)

# Ensure X_train_dense and y_train have consistent lengths
assert X_train_dense.shape[0] == y_train.shape[0], "X_train and y_train must have the same number of samples."

# Define sample size (10% of original data)
sample_size = int(0.1 * X_train_dense.shape[0])

# Randomly sample 10% of the training set
X_train_sampled, y_train_sampled = resample(X_train_dense, y_train, n_samples=sample_size, random_state=42)

# Loop through different models and apply optimizations
for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):
    with mlflow.start_run():
        
        # Log parameters and artifacts
        mlflow.log_param("train-data-path", "/datasets/dtc/green_tripdata_2021-01.parquet")
        #mlflow.log_param("train-data-path", "https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-01.parquet")
        mlflow.log_param("sample-size-train-data", df_train.shape[0])  # Record the number of samples taken
        mlflow.log_param("valid-data-path", "/datasets/dtc/green_tripdata_2021-02.parquet")
        #mlflow.log_param("valid-data-path", "https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-02.parquet")
        mlflow.log_param("sample-size-valid-data", df_valid.shape[0])  # Record the number of samples taken
        
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        # Configure the model based on its class
        if model_class == LinearSVR:
            # Set parameters for LinearSVR
            mlmodel = model_class(max_iter=1000, dual=True, tol=1e-2)  # Use dual=True for compatibility
        elif model_class in (RandomForestRegressor, ExtraTreesRegressor):
            # Use parallel processing for tree-based models
            mlmodel = model_class(n_jobs=-1)
        elif model_class == GradientBoostingRegressor:
            # Enable early stopping for Gradient Boosting
            mlmodel = model_class(n_iter_no_change=5, validation_fraction=0.1)
        else:
            mlmodel = model_class()

        # Fit the model using the sampled training data
        mlmodel.fit(X_train_sampled, y_train_sampled)

        # Make predictions using the original validation set
        y_pred = mlmodel.predict(X_val_dense)

        # Log RMSE using the original validation set
        rmse = root_mean_squared_error(y_val, y_pred)
        #rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

        # Print training time
        print(f"Finished training {model_class.__name__} with RMSE: {rmse}")
# Out:
# Shape of X_train before any transformation: (7391, 3418)
# Shape of y_train before any transformation: (7391,)
# Shape of X_train_dense after conversion: (7391, 3418)
# Shape of y_train after conversion: (7391,)
# Finished training RandomForestRegressor with RMSE: 7.259841238023631
# Finished training GradientBoostingRegressor with RMSE: 7.020166648537414
# Finished training ExtraTreesRegressor with RMSE: 7.403640765063365
# Finished training LinearSVR with RMSE: 1506.4530306035401
